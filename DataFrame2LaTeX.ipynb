# %%
import pandas as pd

# %%
file = pd.read_csv('D:/UFRN/NAOS/BStars_2024att/sdB/Final_Table_sdB.csv', sep=';')
file
# Out:
#           TIC          GaiaDR3Name log(g)  Mass  Period  ePeriod  t_span  \
# 0    39174351  4030308460578827264    5.6  0.47   0.278    0.002      41
# 1    47763235  2924859847973986048    ---   ---   0.203    0.002      45
# 2    55753808  1575432697534110336    5.9  0.47   0.201    0.001      95
# 3    67423472   344155939885410816    5.6  0.47   0.188    0.001      46
# 4    68495594   937565831431448192    ---   ---   0.038    0.001     131
# 5    95526898  3744968013301724544    5.6  0.47   0.241    0.002      33
# 6    99641129  1102107819544067456    5.7  0.47   0.092    0.001      83
# 7   137306463  2051770507972278016    5.7  0.47   0.283    0.003      69
# 8   137608661  1132110502568387968    5.6  0.47   0.291    0.001     156
# 9   138618727   859683853719128192    5.4  0.46   0.332    0.001     114
# 10  148785530  1375814952762454272    5.5  0.47   0.157    0.001      53
# 11  158387021  2105469320138052864    5.6  0.47   0.567    0.006     132
# ...

# %%
print(file.to_latex(index=False, formatters={"name": str.upper}, float_format="{:.3f}".format))
# Out:
# \begin{tabular}{rrllrrrrr}
# \toprule
#       TIC &         GaiaDR3Name & log(g) & Mass &  Period &  ePeriod &  t\_span &  N\_cycle &  CROWD \\
# \midrule
#  39174351 & 4030308460578827264 &    5.6 & 0.47 &   0.278 &    0.002 &      41 &  147.482 &  0.994 \\
#  47763235 & 2924859847973986048 &    --- &  --- &   0.203 &    0.002 &      45 &  221.675 &  0.997 \\
#  55753808 & 1575432697534110336 &    5.9 & 0.47 &   0.201 &    0.001 &      95 &  472.637 &  0.441 \\
#  67423472 &  344155939885410816 &    5.6 & 0.47 &   0.188 &    0.001 &      46 &  244.681 &  0.993 \\
#  68495594 &  937565831431448192 &    --- &  --- &   0.038 &    0.001 &     131 & 3447.368 &  0.612 \\
#  95526898 & 3744968013301724544 &    5.6 & 0.47 &   0.241 &    0.002 &      33 &  136.929 &  0.836 \\
#  99641129 & 1102107819544067456 &    5.7 & 0.47 &   0.092 &    0.001 &      83 &  902.174 &  0.677 \\
# 137306463 & 2051770507972278016 &    5.7 & 0.47 &   0.283 &    0.003 &      69 &  243.816 &  0.613 \\
# ...
